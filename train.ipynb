# %%
import numpy as np
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
import torch
import matplotlib.pyplot as plt
# %run game
# %run preprocessor
import torch
import pathlib
# %run ./ddqn/ddqn_agent

right_run = [False,True,False,True,False]

n_frames = 4
n_channels = 3
original_width = 256
original_height = 240
scaled_width = 84
scaled_height = 84

game_visible = True
mario_scale = 2.0
mario_state = 0
mario_timer = 200
mario_fps = 30
level_path = "/levels/custom/flat.txt"

preprocess = Preprocessor(n_frames, n_channels, original_height, original_width, scaled_height, scaled_width)
game = Game(game_visible, mario_scale, mario_state, mario_timer, mario_fps, level_path, preprocess)




BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10
num_episodes = 5

episodes = [1]

for n_episodes in episodes:
    agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TARGET_UPDATE, n_episodes, n_channels, scaled_height, scaled_width, game)
    agent.train()
# Out:
# Training episode: 0
# Initialising start state
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Best action
# Game Status RUNNING
# [] []
# Random action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Random action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Best action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Random action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Random action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Best action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Random action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Best action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Random action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Random action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Random action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Best action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Random action
# Game Status RUNNING
# torch.Size([512, 1]) torch.Size([4, 128])
# torch.Size([4, 1, 128]) torch.Size([4, 128])
# [] []
# Best action
# Game Status RUNNING
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-4c065c10dfcd> in <module>
#      44 for n_episodes in episodes:
#      45     agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TARGET_UPDATE, n_episodes, n_channels, scaled_height, scaled_width, game)
# ---> 46     agent.train()
#      47
#      48
#
# ~\Desktop\Uni\Year 4\ECM3401 Individual Literature and Review Project\dev\marioai\mario-rl-client\ddqn\ddqn_agent.py in train(self)
#     210                 # Perform one step of the optimization (on the target network)
#     211                 # Save the loss
# --> 212                 self.optimize_model()
#     213
#     214
#
# ~\Desktop\Uni\Year 4\ECM3401 Individual Literature and Review Project\dev\marioai\mario-rl-client\ddqn\ddqn_agent.py in optimize_model(self)
#     290         # state value or 0 in case the state was final.
#     291         next_state_values = torch.zeros(self.BATCH_SIZE, device=device).repeat(4, 1)
# --> 292         next_state_values[non_final_mask] = self.target_net(non_final_next_states).max(1)[0].detach()
#     293         # Compute the expected Q values
#     294         expected_state_action_values = (next_state_values * self.GAMMA) + reward_batch
#
# ~\Anaconda3\envs\marioenv\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Desktop\Uni\Year 4\ECM3401 Individual Literature and Review Project\dev\marioai\mario-rl-client\ddqn\ddqn_agent.py in forward(self, x)
#      45     # during optimization. Returns tensor([[left0exp,right0exp]...]).
#      46     def forward(self, x):
# ---> 47         x = F.relu(self.bn1(self.conv1(x)))
#      48         x = F.relu(self.bn2(self.conv2(x)))
#      49         x = F.relu(self.bn3(self.conv3(x)))
#
# ~\Anaconda3\envs\marioenv\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~\Anaconda3\envs\marioenv\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# ~\Anaconda3\envs\marioenv\lib\site-packages\torch\nn\modules\conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# KeyboardInterrupt:

# %%
import numpy as np
import pandas as pd
loss = np.array([0.5, 0.9])

loss = np.expand_dims(loss, axis=1)

eps = np.array([1, 2])

eps = np.expand_dims(eps, axis=1)


loss_eps = np.append(loss, eps, axis=1)

a = np.array([])
a = np.append(a, 3)
a
# Out:
# array([3.])
