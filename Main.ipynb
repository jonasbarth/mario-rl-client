# %%
# %run Client.ipynb
# %run DDQN_Agent.ipynb

import torch
import pathlib

BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10
screen_width = 84
screen_height = 84
num_episodes = 1

API_endpoint = "http://ec2-18-208-230-235.compute-1.amazonaws.com:8080"
client = Client(API_endpoint)


agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TARGET_UPDATE, num_episodes, screen_height, screen_width, client)
agent.train()
# Out:
# Training episode: 0
# /levels/custom/quick_victory_3.txt
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Initialising start state
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[6]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -6.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -6.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[3]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[3]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[3]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -6.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[3]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[3]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[6]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[1]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -6.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[1]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[1]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -5.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[1]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[1]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[6]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[7]]) and got reward -6.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -6.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[3]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[3]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[1]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[6]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[1]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[6]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[5]]) and got reward -4.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[0]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[3]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward -2.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[4]]) and got reward -3.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[3]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Best action
# Action selected
# Taking action
# Took action tensor([[2]]) and got reward 0.0
# Game Status RUNNING
# Pushing transition to memory
# Optimising model
# Selecting action
# torch.Size([4, 3, 84, 84])
# Random action
# Action selected
# Taking action
# Took action tensor([[1]]) and got reward 14.0
# Game Status None
# Pushing transition to memory
# Optimising model
# Episode 0 finished
# Training finished
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-3-9937bf79a7dd> in <module>
#      20
#      21 agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TARGET_UPDATE, num_episodes, screen_height, screen_width, client)
# ---> 22 agent.train()
#
# <ipython-input-3-ab2a2f512c6d> in train(self)
#     211
#     212         print("Training finished")
# --> 213         self.save(str(pathlib.Path().absolute()))
#     214
#     215
#
# <ipython-input-3-ab2a2f512c6d> in save(self, path)
#     324
#     325     def save(self, path):
# --> 326         torch.save(self.policy_net.state_dict(), path + "policy.pt")
#     327         print("Saved the policy net")
#     328         torch.save(self.target_net.state_dict(), path + "target.pt")
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     325             return
#     326
# --> 327     with _open_file_like(f, 'wb') as opened_file:
#     328         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#     329
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     210 def _open_file_like(name_or_buffer, mode):
#     211     if _is_path(name_or_buffer):
# --> 212         return _open_file(name_or_buffer, mode)
#     213     else:
#     214         if 'w' in mode:
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in __init__(self, name, mode)
#     191 class _open_file(_opener):
#     192     def __init__(self, name, mode):
# --> 193         super(_open_file, self).__init__(open(name, mode))
#     194
#     195     def __exit__(self, *args):
#
# PermissionError: [Errno 13] Permission denied: '/home/jupyterpolicy.pt'

# %%
client.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1ef8b845d8fa> in <module>
# ----> 1 client.close()
#
# <ipython-input-7-e08cd823552e> in close(self)
#      70
#      71     def close(self):
# ---> 72         r.requests.get(url = self.API_endpoint + "/close")
#      73
#      74     def win(self):
#
# NameError: name 'r' is not defined
