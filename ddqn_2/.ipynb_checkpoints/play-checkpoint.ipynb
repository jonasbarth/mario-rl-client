# %%
import numpy as np
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
import torch
import matplotlib.pyplot as plt
# %run game
# %run preprocessor
import torch
import pathlib
# %run ./DQN_learn


right_run = [False,True,False,True,False]

n_frames = 1
n_channels = 3
original_width = 256
original_height = 240
scaled_width = 84
scaled_height = 84

game_visible = True
mario_scale = 2.0
mario_state = 0
mario_timer = 200
mario_fps = 30
level_path = "/levels/custom/quick_victory_4.txt"

preprocess = Preprocessor(n_frames, n_channels, original_height, original_width, scaled_height, scaled_width)
game = Game(game_visible, mario_scale, mario_state, mario_timer, mario_fps, level_path, preprocess)




BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10
num_episodes = 5

episodes = [1]

agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TARGET_UPDATE, num_episodes, n_channels, scaled_height, scaled_width, game)
agent.load_model("./ddqn/models/epochs_1000_quick_victory_4_")
agent.play(1)
#for n_episodes in episodes:
    #agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TARGET_UPDATE, n_episodes, n_channels, scaled_height, scaled_width, game)
    #agent.train()
# Out:
# Loaded the policy net
# Loaded the target net
# Playing episode 0
# Initialising start state
# Game Status RUNNING
# Reward: -2.8660011
# Game Status RUNNING
# Reward: -2.8660011
# Game Status RUNNING
# Reward: -2.8660011
# Game Status RUNNING
# Reward: -2.8660011
# Game Status RUNNING
# Reward: -2.8660011
# Game Status RUNNING
# Reward: -2.8660011
# Game Status RUNNING
# Reward: -2.8660011
# Game Status RUNNING
# Reward: -2.8660011
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.866005
# Game Status RUNNING
# Reward: -2.8659973
# Game Status RUNNING
# Reward: -2.8659973
# Game Status RUNNING
# Reward: -2.8659973
# Game Status RUNNING
# Reward: -2.8659973
# Game Status RUNNING
# Reward: -2.8659973
# Game Status RUNNING
# Reward: -2.8659973
# Game Status RUNNING
# Reward: -2.8659973
# Game Status RUNNING
# Reward: -2.8659973
# Game Status RUNNING
# Reward: -2.8659973
# Game Status RUNNING
# Reward: 0.064468384
# Game Status RUNNING
# Reward: 2.614624
# Game Status RUNNING
# Reward: 2.1824036
# Game Status RUNNING
# Reward: 1.9112244
# Game Status RUNNING
# Reward: 1.7410583
# Game Status RUNNING
# Reward: 1.6343231
# Game Status RUNNING
# Reward: 1.567337
# Game Status RUNNING
# Reward: 1.5253143
# Game Status RUNNING
# Reward: 3.531189
# Game Status RUNNING
# Reward: 4.7897034
# Game Status RUNNING
# Reward: -1.3433838
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# Game Status RUNNING
# Reward: -4.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-c2bc0d973e3d> in <module>
#      45 agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TARGET_UPDATE, num_episodes, n_channels, scaled_height, scaled_width, game)
#      46 agent.load_model("./ddqn/models/epochs_1000_quick_victory_4_")
# ---> 47 agent.play(1)
#      48 #for n_episodes in episodes:
#      49     #agent = DQNAgent(BATCH_SIZE, GAMMA, EPS_START, EPS_END, EPS_DECAY, TARGET_UPDATE, n_episodes, n_channels, scaled_height, scaled_width, game)
#
# ~\Desktop\Uni\Year 4\ECM3401 Individual Literature and Review Project\dev\marioai\mario-rl-client\ddqn\ddqn_agent.py in play(self, num_epochs)
#     387                 #print("Action selected")
#     388                 #print("Taking action")
# --> 389                 next_state, reward, game_status = self.game.step(action)
#     390
#     391                 eps_reward = np.append(eps_reward, reward)
#
# ~\Desktop\Uni\Year 4\ECM3401 Individual Literature and Review Project\dev\marioai\mario-rl-client\game.py in step(self, action)
#      44         action = self.tensor_to_action(action)
#      45         java_list = ListConverter().convert(action, self.gateway._gateway_client)
# ---> 46         obs = self.gateway.entry_point.executeAction(java_list)
#      47
#      48         reward = obs.getValue()
#
# ~\Anaconda3\envs\marioenv\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1282             proto.END_COMMAND_PART
#    1283
# -> 1284         answer = self.gateway_client.send_command(command)
#    1285         return_value = get_return_value(
#    1286             answer, self.gateway_client, self.target_id, self.name)
#
# ~\Anaconda3\envs\marioenv\lib\site-packages\py4j\java_gateway.py in send_command(self, command, retry, binary)
#    1012         connection = self._get_connection()
#    1013         try:
# -> 1014             response = connection.send_command(command)
#    1015             if binary:
#    1016                 return response, self._create_connection_guard(connection)
#
# ~\Anaconda3\envs\marioenv\lib\site-packages\py4j\java_gateway.py in send_command(self, command)
#    1179
#    1180         try:
# -> 1181             answer = smart_decode(self.stream.readline()[:-1])
#    1182             logger.debug("Answer received: {0}".format(answer))
#    1183             if answer.startswith(proto.RETURN_MESSAGE):
#
# ~\Anaconda3\envs\marioenv\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
